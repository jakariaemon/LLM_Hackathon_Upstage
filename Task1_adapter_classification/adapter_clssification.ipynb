# %%
# !pip install -q predibase datasets
# Out:
# & was unexpected at this time.
# The value specified in an AutoRun registry key could not be parsed.
# WARNING: typer 0.12.3 does not provide the extra 'all'
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gradio 4.37.2 requires urllib3~=2.0, but you have urllib3 1.26.12 which is incompatible.

# %%
import warnings

warnings.filterwarnings("ignore")

# %%
from datasets import load_dataset
import csv

def hfdataset_to_csv(datalist: list, csv_file_name, max=-1):
  template = {
        "prompt":
        """<|im_start|>system\nYou are an expert classifer. Based on the given Sentece, Classfity them as one of the four category:korean general law, korean business law, japanese general law,japanese business law  <|im_end|>
<|im_start|>Input\n {content}
<|im_start|>Class\n""",
        "completion": "{headline}<|im_end|>",
        "split": "train"}


  with open(csv_file_name, 'w', newline='') as csvfile:
    fieldnames = template.keys()
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    for i, d in enumerate(datalist):
      if i >= max:
        break
      row = {
          "prompt": template["prompt"].format(content=d["question"]),
          "completion": template["completion"].format(headline=d["adapter_name"]),
          "split": "train"
      }
      writer.writerow(row)

# %%
def validate_data_csv(csv_file_name):
  """ Make sure it has prompt, completion, and split with all values """
  with open(csv_file_name, 'r') as f:
    reader = csv.DictReader(f)
    for row in reader:
      assert row['prompt']
      assert row['completion']
      assert row['split']

  return True

# %%
from tokenizers import Tokenizer
tokenizer = Tokenizer.from_pretrained("upstage/solar-1-mini-tokenizer")

def compute_cost(csv_file_name, price_per_million_tokens=0.5):
  """ Compute the cost of the dataset """

  total_num_of_tokens = 0
  with open(csv_file_name, 'r') as f:
    reader = csv.DictReader(f)
    # get all values
    values = [row['completion']+ " " + row['prompt'] for row in reader]
    for value in values:
      # tokenize
      enc = tokenizer.encode(value)
      num_of_tokens = len(enc.tokens)
      total_num_of_tokens += num_of_tokens


  return total_num_of_tokens / 1000000 * price_per_million_tokens

# %%
from datasets import load_dataset, Dataset
from sklearn.model_selection import train_test_split

# Load the dataset
hfdataset = load_dataset("csv", data_files="adapter_classification.csv")
train_hfdataset = hfdataset["train"]
print(train_hfdataset)
# Convert the dataset to a pandas DataFrame for easier manipulation
train_df = train_hfdataset.to_pandas()

# Split the train dataset into 80% train and 20% test
train_split, test_split = train_test_split(train_df, test_size=0.1, random_state=42)

train_split.reset_index(drop=True, inplace=True)
test_split.reset_index(drop=True, inplace=True)

# Convert back to the Hugging Face Dataset format
train_dataset = Dataset.from_pandas(train_split)
test_dataset = Dataset.from_pandas(test_split)

# Print the sizes of the new datasets
print(f"Train dataset size: {len(train_dataset)}")
print(f"Test dataset size: {len(test_dataset)}")
print(train_dataset)
# Out:
# Dataset({
#     features: ['question', 'adapter_name'],
#     num_rows: 2000
# })
# Train dataset size: 1800
# Test dataset size: 200
# Dataset({
#     features: ['question', 'adapter_name'],
#     num_rows: 1800
# })

# %%
dataset_name = "adapter_train_dataset_1800"
csv_file_name = f"{dataset_name}.csv"
try:
  pb_dataset = pb.datasets.get(dataset_name)
  print(f"Dataset found: {pb_dataset}")
except RuntimeError:
  print("Dataset not found, creating...")

  hfdataset_to_csv(train_dataset, csv_file_name, max=1800)

  print(f"Dataset Validation: {validate_data_csv(csv_file_name)}")
  print(f"One step FT Cost: {compute_cost(csv_file_name)} USD")

  #print("Uploading daatset...")
  pb_dataset = pb.datasets.from_file(csv_file_name, name=dataset_name)
# Out:
# Dataset found: uuid='5bffbbac-3a56-49b9-a197-bee620959817' name='adapter_train_dataset_1800' connection_type='file' connection_name='file_uploads' status='connected'

# %%
repo_name = "adapter-classifer-01"
repo = pb.repos.create(name=repo_name, description="Upstage_Hackathon_KGL_Adapter", exists_ok=True)
print(repo)
# Out:
# uuid='183e5ef8-124b-4b00-9fe5-9f27266b0484' name='adapter-classifer-01' description='Upstage_Hackathon_KGL_Adapter'

# %%
adapter = pb.adapters.create(
    config=FinetuningConfig(
        base_model="solar-1-mini-chat-240612",
        epochs=3, # default: 3
        rank=16, # default: 16
    ),
    dataset=pb_dataset, # Also accepts the dataset name as a string
    repo=repo,
    description="initial model with defaults"
)
# Out:
# Successfully requested finetuning of solar-1-mini-chat-240612 as `adapter-classifer-01/2`. (Job UUID: 0245a50d-1bfc-4fca-8c5f-c360e67d2fd3).
#
# Watching progress of finetuning job 0245a50d-1bfc-4fca-8c5f-c360e67d2fd3. This call will block until the job has finished. Canceling or terminating this call will NOT cancel or terminate the job itself.
#
# Job is starting. Total queue time: 0:00:47
# Waiting to receive training metrics...
#
# ┌────────────┬────────────┬─────────────────┐
# │ checkpoint │ train_loss │ validation_loss │
# ├────────────┼────────────┼─────────────────┤
# │     1      │   0.0000   │        --       │
# └────────────┴────────────┴─────────────────┘

# %%
adapter
# Out:
# Adapter(repo='adapter-classifer-01', tag=2, archived=False, base_model='solar-1-mini-chat-240612', description='initial model with defaults', artifact_path='0245a50d-1bfc-4fca-8c5f-c360e67d2fd3/52546414125f4180872c76b3bf450da6/artifacts/model/model_weights', finetuning_error=None, finetuning_job_uuid='0245a50d-1bfc-4fca-8c5f-c360e67d2fd3')

# %%
adapter_id = adapter.repo + "/" + str(adapter.tag)
adapter_id
# Out:
# 'adapter-classifer-01/2'

# %%
input_prompt="""
<|im_start|>system\nYou are an expert classifer. Based on the given Sentece, Classfity them as one of the four category:korean general law, korean business law, japanese general law,japanese business law<|im_end|>
<|im_start|>Input
피고인은 언제, 어디서, 어떤 차량을 운전했습니까? <|im_end|>
<|im_start|>Class 
"""

# %%
# CURL test
import requests
import json

url = "https://serving.app.predibase.com/7ea6d0/deployments/v2/llms/solar-1-mini-chat-240612/generate"


payload = {
    "inputs": input_prompt,
    "parameters": {
        "adapter_id": adapter_id,
        "adapter_source": "pbase",
        "max_new_tokens": 60,
        "temperature": 0.1
    }
}

headers = {
    "Content-Type": "application/json",
    "Authorization": f"Bearer {api_token}"
}

response = requests.post(url, data=json.dumps(payload), headers=headers)

print(response.text)
# Out:
# {"generated_text":"korean general law"}

# %%
# !pip -q install langchain langchain-upstage solar-as-judge
# Out:
# & was unexpected at this time.
# The value specified in an AutoRun registry key could not be parsed.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\emon\anaconda3\Lib\site-packages\~ydantic_core'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gradio 4.37.2 requires urllib3~=2.0, but you have urllib3 1.26.12 which is incompatible.

# %%
lorax_client = pb.deployments.client("solar-1-mini-chat-240612")

# %%
# Create test dataset
test_csv_file_name = f"adapter_test_dataset"
hfdataset_to_csv(test_dataset, test_csv_file_name, max=200)

win_results = {"A_wins":0, "B_wins": 0, "tie": 0,  "A_score": 0, "B_score": 0}
with open(test_csv_file_name, 'r') as f:
  reader = csv.DictReader(f)
  for row in reader:
    prompt = row['prompt']
    ground_truth = row['completion']
    A_answer = lorax_client.generate(prompt, max_new_tokens=1000).generated_text
    B_answer = lorax_client.generate(prompt, adapter_id=adapter_id, max_new_tokens=1000).generated_text

    A_score, B_score = saj.judge(prompt, A_answer, B_answer, ground_truth)
    print( A_score, B_score, A_answer, B_answer)
    win_results["A_score"] += A_score
    win_results["B_score"] += B_score
    if A_score > B_score:
      win_results["A_wins"] += 1
    elif B_score > A_score:
      win_results["B_wins"] += 1
    else:
      win_results["tie"] += 1
    print(win_results)
# Out:
# 2 10 korean business law japanese business law
# {'A_wins': 0, 'B_wins': 1, 'tie': 0, 'A_score': 2, 'B_score': 10}
# 0 0 korean general law korean general law
# {'A_wins': 0, 'B_wins': 1, 'tie': 1, 'A_score': 2, 'B_score': 10}
# 0 0 일본 일반법 japanese general law
# {'A_wins': 0, 'B_wins': 1, 'tie': 2, 'A_score': 2, 'B_score': 10}
# 0 0 korean business law korean business law
# {'A_wins': 0, 'B_wins': 1, 'tie': 3, 'A_score': 2, 'B_score': 10}
# Invalid json output: The provided answer is: japanese general law
#
# Based on the prompt and the ground truth, I evaluate the answer as follows:
#
# {"score": 5}
# 0 0 日本の一般法 japanese general law
# {'A_wins': 0, 'B_wins': 1, 'tie': 4, 'A_score': 2, 'B_score': 10}
# 0 0 日本の一般法 japanese general law
# {'A_wins': 0, 'B_wins': 1, 'tie': 5, 'A_score': 2, 'B_score': 10}
# 0 0 korean business law korean business law
# {'A_wins': 0, 'B_wins': 1, 'tie': 6, 'A_score': 2, 'B_score': 10}
# 2 10 korean business law japanese business law
# {'A_wins': 0, 'B_wins': 2, 'tie': 6, 'A_score': 4, 'B_score': 20}
# 0 0 korean general law korean general law
# {'A_wins': 0, 'B_wins': 2, 'tie': 7, 'A_score': 4, 'B_score': 20}
# 0 0 japanese general law japanese general law
# {'A_wins': 0, 'B_wins': 2, 'tie': 8, 'A_score': 4, 'B_score': 20}
# 0 0 korean general law korean general law
# {'A_wins': 0, 'B_wins': 2, 'tie': 9, 'A_score': 4, 'B_score': 20}
# 0 0 日本の一般法 japanese general law
# {'A_wins': 0, 'B_wins': 2, 'tie': 10, 'A_score': 4, 'B_score': 20}
# 0 0 日本の一般法 japanese general law
# {'A_wins': 0, 'B_wins': 2, 'tie': 11, 'A_score': 4, 'B_score': 20}
# Error code: 429 - {'error_code': 'TOO_MANY_REQUESTS', 'message': {'en': "Thanks for loving our service. You've sent too many requests in a short time. Please try again later. For further help, contact console@upstage.ai"}}
# 0 0 korean business law korean business law
# {'A_wins': 0, 'B_wins': 2, 'tie': 12, 'A_score': 4, 'B_score': 20}
# 0 0 korean general law korean general law
# {'A_wins': 0, 'B_wins': 2, 'tie': 13, 'A_score': 4, 'B_score': 20}
# 0 0 한국 일반법 korean general law
# {'A_wins': 0, 'B_wins': 2, 'tie': 14, 'A_score': 4, 'B_score': 20}
# 0 0 korean general law korean business law
# {'A_wins': 0, 'B_wins': 2, 'tie': 15, 'A_score': 4, 'B_score': 20}
# Error code: 429 - {'error_code': 'TOO_MANY_REQUESTS', 'message': {'en': "Thanks for loving our service. You've sent too many requests in a short time. Please try again later. For further help, contact console@upstage.ai"}}
# 0 0 한국 일반법 korean general law
# {'A_wins': 0, 'B_wins': 2, 'tie': 16, 'A_score': 4, 'B_score': 20}
# 2 10 japanese general law japanese business law
# {'A_wins': 0, 'B_wins': 3, 'tie': 16, 'A_score': 6, 'B_score': 30}
# 2 10 japanese general law japanese business law
# {'A_wins': 0, 'B_wins': 4, 'tie': 16, 'A_score': 8, 'B_score': 40}
# Error code: 429 - {'error_code': 'TOO_MANY_REQUESTS', 'message': {'en': "Thanks for loving our service. You've sent too many requests in a short time. Please try again later. For further help, contact console@upstage.ai"}}
# Error code: 429 - {'error_code': 'TOO_MANY_REQUESTS', 'message': {'en': "Thanks for loving our service. You've sent too many requests in a short time. Please try again later. For further help, contact console@upstage.ai"}}
# 0 0 korean general law korean business law
# {'A_wins': 0, 'B_wins': 4, 'tie': 17, 'A_score': 8, 'B_score': 40}
# 2 10 japanese general law japanese business law
# {'A_wins': 0, 'B_wins': 5, 'tie': 17, 'A_score': 10, 'B_score': 50}
# 2 10 korean general law japanese business law
# {'A_wins': 0, 'B_wins': 6, 'tie': 17, 'A_score': 12, 'B_score': 60}
# 2 10 japanese business law japanese general law
# {'A_wins': 0, 'B_wins': 7, 'tie': 17, 'A_score': 14, 'B_score': 70}
# 2 10 korean business law japanese business law
# {'A_wins': 0, 'B_wins': 8, 'tie': 17, 'A_score': 16, 'B_score': 80}
# 0 0 korean general law korean general law
# {'A_wins': 0, 'B_wins': 8, 'tie': 18, 'A_score': 16, 'B_score': 80}
# Error code: 429 - {'error_code': 'TOO_MANY_REQUESTS', 'message': {'en': "Thanks for loving our service. You've sent too many requests in a short time. Please try again later. For further help, contact console@upstage.ai"}}
# 0 0 日本の一般法 japanese general law
# {'A_wins': 0, 'B_wins': 8, 'tie': 19, 'A_score': 16, 'B_score': 80}
# Invalid json output: It is not clear from the prompt what the input is or what the ground truth is. Please provide more information.
# 2 7 korean general law korean business law
# {'A_wins': 0, 'B_wins': 9, 'tie': 19, 'A_score': 18, 'B_score': 87}
# 4 10 korean general law korean business law
# {'A_wins': 0, 'B_wins': 10, 'tie': 19, 'A_score': 22, 'B_score': 97}
# 0 0 korean general law korean general law
# {'A_wins': 0, 'B_wins': 10, 'tie': 20, 'A_score': 22, 'B_score': 97}
# 2 10 korean general law korean business law
# {'A_wins': 0, 'B_wins': 11, 'tie': 20, 'A_score': 24, 'B_score': 107}
# 0 0 korean business law korean business law
# {'A_wins': 0, 'B_wins': 11, 'tie': 21, 'A_score': 24, 'B_score': 107}
# 2 10 korean general law korean business law
# {'A_wins': 0, 'B_wins': 12, 'tie': 21, 'A_score': 26, 'B_score': 117}
# Error code: 429 - {'error_code': 'TOO_MANY_REQUESTS', 'message': {'en': "Thanks for loving our service. You've sent too many requests in a short time. Please try again later. For further help, contact console@upstage.ai"}}
# 0 0 korean business law korean business law
# {'A_wins': 0, 'B_wins': 12, 'tie': 22, 'A_score': 26, 'B_score': 117}
# 0 0 日本の一般法 japanese general law
# {'A_wins': 0, 'B_wins': 12, 'tie': 23, 'A_score': 26, 'B_score': 117}
# 0 0 korean general law korean general law
# {'A_wins': 0, 'B_wins': 12, 'tie': 24, 'A_score': 26, 'B_score': 117}
# 0 0 japanese business law japanese business law
# {'A_wins': 0, 'B_wins': 12, 'tie': 25, 'A_score': 26, 'B_score': 117}
# Invalid json output: The provided answer is accurate and relevant to the input question, as it correctly identifies the category of the given sentence as "japanese general law". Based on the ground truth provided, the answer is in line with the expected classification. Therefore, I would rate the answer as a 5 on the Likert scale, indicating a very good answer.
#
# {"score": 5}
# 0 0 日本の一般法 japanese general law
# {'A_wins': 0, 'B_wins': 12, 'tie': 26, 'A_score': 26, 'B_score': 117}
# 2 10  japanese business law japanese general law
# {'A_wins': 0, 'B_wins': 13, 'tie': 26, 'A_score': 28, 'B_score': 127}
# 0 0 korean general law korean general law
# {'A_wins': 0, 'B_wins': 13, 'tie': 27, 'A_score': 28, 'B_score': 127}
# 0 0 korean general law korean general law
# {'A_wins': 0, 'B_wins': 13, 'tie': 28, 'A_score': 28, 'B_score': 127}
# Invalid json output: Based on the given sentence, it appears to be asking about the number of paid leaves granted to employees who have worked for six consecutive months. This topic falls under the category of employment laws, which is typically covered in business law. Furthermore, the sentence does not specify any particular country, so it could apply to both Japanese and Korean business law. However, since the question is more specific to a general employment law rather than a specific country's law, I would choose Answer B: korean business law.
#
# {"winner": "B"}
# 2 10 korean business law japanese business law
# {'A_wins': 0, 'B_wins': 14, 'tie': 28, 'A_score': 30, 'B_score': 137}
# 0 0 korean general law korean general law
# {'A_wins': 0, 'B_wins': 14, 'tie': 29, 'A_score': 30, 'B_score': 137}
# 0 0 korean business law korean business law
# {'A_wins': 0, 'B_wins': 14, 'tie': 30, 'A_score': 30, 'B_score': 137}
# 2 10 korean business law japanese business law
# {'A_wins': 0, 'B_wins': 15, 'tie': 30, 'A_score': 32, 'B_score': 147}
# 2 10 korean general law korean business law
# {'A_wins': 0, 'B_wins': 16, 'tie': 30, 'A_score': 34, 'B_score': 157}
# 2 10 korean general law korean business law
# {'A_wins': 0, 'B_wins': 17, 'tie': 30, 'A_score': 36, 'B_score': 167}
# 0 0 korean general law korean business law
# {'A_wins': 0, 'B_wins': 17, 'tie': 31, 'A_score': 36, 'B_score': 167}
# 0 0 한국 일반법 korean general law
# {'A_wins': 0, 'B_wins': 17, 'tie': 32, 'A_score': 36, 'B_score': 167}
# 0 0 japanese business law japanese business law
# {'A_wins': 0, 'B_wins': 17, 'tie': 33, 'A_score': 36, 'B_score': 167}
# 0 0 japanese business law japanese business law
# {'A_wins': 0, 'B_wins': 17, 'tie': 34, 'A_score': 36, 'B_score': 167}
# Error code: 429 - {'error_code': 'TOO_MANY_REQUESTS', 'message': {'en': "Thanks for loving our service. You've sent too many requests in a short time. Please try again later. For further help, contact console@upstage.ai"}}
# 0 0 korean general law korean general law
# {'A_wins': 0, 'B_wins': 17, 'tie': 35, 'A_score': 36, 'B_score': 167}
# 2 10 japanese business law japanese general law
# {'A_wins': 0, 'B_wins': 18, 'tie': 35, 'A_score': 38, 'B_score': 177}
# 0 0 korean general law korean general law
# {'A_wins': 0, 'B_wins': 18, 'tie': 36, 'A_score': 38, 'B_score': 177}
# 0 0 korean business law korean business law
# {'A_wins': 0, 'B_wins': 18, 'tie': 37, 'A_score': 38, 'B_score': 177}
# 2 10 korean business law japanese business law
# {'A_wins': 0, 'B_wins': 19, 'tie': 37, 'A_score': 40, 'B_score': 187}
# 0 0 日本の一般法 japanese general law
# {'A_wins': 0, 'B_wins': 19, 'tie': 38, 'A_score': 40, 'B_score': 187}
# 2 10 korean business law japanese business law
# {'A_wins': 0, 'B_wins': 20, 'tie': 38, 'A_score': 42, 'B_score': 197}
# 0 0 日本の一般法 japanese general law
# {'A_wins': 0, 'B_wins': 20, 'tie': 39, 'A_score': 42, 'B_score': 197}
# Error code: 429 - {'error_code': 'TOO_MANY_REQUESTS', 'message': {'en': "Thanks for loving our service. You've sent too many requests in a short time. Please try again later. For further help, contact console@upstage.ai"}}
# 0 0 korean general law korean general law
# {'A_wins': 0, 'B_wins': 20, 'tie': 40, 'A_score': 42, 'B_score': 197}
# 0 0 日本の一般法 japanese general law
# {'A_wins': 0, 'B_wins': 20, 'tie': 41, 'A_score': 42, 'B_score': 197}
# 2 8 korean general law korean business law
# {'A_wins': 0, 'B_wins': 21, 'tie': 41, 'A_score': 44, 'B_score': 205}
# 2 10 korean business law japanese business law
# {'A_wins': 0, 'B_wins': 22, 'tie': 41, 'A_score': 46, 'B_score': 215}
# 0 0 日本の一般法 japanese general law
# {'A_wins': 0, 'B_wins': 22, 'tie': 42, 'A_score': 46, 'B_score': 215}
# 2 10 korean business law japanese business law
# {'A_wins': 0, 'B_wins': 23, 'tie': 42, 'A_score': 48, 'B_score': 225}
# Error code: 429 - {'error_code': 'TOO_MANY_REQUESTS', 'message': {'en': "Thanks for loving our service. You've sent too many requests in a short time. Please try again later. For further help, contact console@upstage.ai"}}
# Error code: 429 - {'error_code': 'TOO_MANY_REQUESTS', 'message': {'en': "Thanks for loving our service. You've sent too many requests in a short time. Please try again later. For further help, contact console@upstage.ai"}}
# 0 0 japanese business law japanese business law
# {'A_wins': 0, 'B_wins': 23, 'tie': 43, 'A_score': 48, 'B_score': 225}
# Error code: 429 - {'error_code': 'TOO_MANY_REQUESTS', 'message': {'en': "Thanks for loving our service. You've sent too many requests in a short time. Please try again later. For further help, contact console@upstage.ai"}}
# 0 0 korean business law korean business law
# {'A_wins': 0, 'B_wins': 23, 'tie': 44, 'A_score': 48, 'B_score': 225}
# 0 0 japanese business law japanese business law
# {'A_wins': 0, 'B_wins': 23, 'tie': 45, 'A_score': 48, 'B_score': 225}
# 0 0 korean general law korean general law
# {'A_wins': 0, 'B_wins': 23, 'tie': 46, 'A_score': 48, 'B_score': 225}
# 0 0 japanese general law japanese general law
# {'A_wins': 0, 'B_wins': 23, 'tie': 47, 'A_score': 48, 'B_score': 225}
# 0 0 日本の一般法 japanese general law
# {'A_wins': 0, 'B_wins': 23, 'tie': 48, 'A_score': 48, 'B_score': 225}
# 0 0 korean general law korean general law
# {'A_wins': 0, 'B_wins': 23, 'tie': 49, 'A_score': 48, 'B_score': 225}
# 0 0 日本の一般法 japanese general law
# {'A_wins': 0, 'B_wins': 23, 'tie': 50, 'A_score': 48, 'B_score': 225}
# 0 0 日本一般法 japanese general law
# {'A_wins': 0, 'B_wins': 23, 'tie': 51, 'A_score': 48, 'B_score': 225}
# 0 0 korean business law korean business law
# {'A_wins': 0, 'B_wins': 23, 'tie': 52, 'A_score': 48, 'B_score': 225}
# 0 0 korean general law korean general law
# {'A_wins': 0, 'B_wins': 23, 'tie': 53, 'A_score': 48, 'B_score': 225}
# 2 10 korean business law japanese business law
# {'A_wins': 0, 'B_wins': 24, 'tie': 53, 'A_score': 50, 'B_score': 235}
# 0 0 korean business law korean business law
# {'A_wins': 0, 'B_wins': 24, 'tie': 54, 'A_score': 50, 'B_score': 235}
# 0 0 korean general law korean general law
# {'A_wins': 0, 'B_wins': 24, 'tie': 55, 'A_score': 50, 'B_score': 235}
# Error code: 429 - {'error_code': 'TOO_MANY_REQUESTS', 'message': {'en': "Thanks for loving our service. You've sent too many requests in a short time. Please try again later. For further help, contact console@upstage.ai"}}
# 0 0 japanese business law japanese business law
# {'A_wins': 0, 'B_wins': 24, 'tie': 56, 'A_score': 50, 'B_score': 235}
# Error code: 429 - {'error_code': 'TOO_MANY_REQUESTS', 'message': {'en': "Thanks for loving our service. You've sent too many requests in a short time. Please try again later. For further help, contact console@upstage.ai"}}
# 0 0 korean general law korean general law
# {'A_wins': 0, 'B_wins': 24, 'tie': 57, 'A_score': 50, 'B_score': 235}
# 2 10 korean general law korean business law
# {'A_wins': 0, 'B_wins': 25, 'tie': 57, 'A_score': 52, 'B_score': 245}
# 0 0 日本一般法 japanese general law
# {'A_wins': 0, 'B_wins': 25, 'tie': 58, 'A_score': 52, 'B_score': 245}
# 2 10 korean business law japanese business law
# {'A_wins': 0, 'B_wins': 26, 'tie': 58, 'A_score': 54, 'B_score': 255}
# 2 10 korean business law japanese business law
# {'A_wins': 0, 'B_wins': 27, 'tie': 58, 'A_score': 56, 'B_score': 265}
# 0 0 日本一般法 japanese general law
# {'A_wins': 0, 'B_wins': 27, 'tie': 59, 'A_score': 56, 'B_score': 265}
# 2 10 korean business law japanese business law
# {'A_wins': 0, 'B_wins': 28, 'tie': 59, 'A_score': 58, 'B_score': 275}
# 0 0 korean general law korean general law
# {'A_wins': 0, 'B_wins': 28, 'tie': 60, 'A_score': 58, 'B_score': 275}
# 0 0 korean general law korean general law
# {'A_wins': 0, 'B_wins': 28, 'tie': 61, 'A_score': 58, 'B_score': 275}
# Error code: 429 - {'error_code': 'TOO_MANY_REQUESTS', 'message': {'en': "Thanks for loving our service. You've sent too many requests in a short time. Please try again later. For further help, contact console@upstage.ai"}}
# 2 10 japanese general law japanese business law
# {'A_wins': 0, 'B_wins': 29, 'tie': 61, 'A_score': 60, 'B_score': 285}
# Invalid json output: The provided answer is incorrect as the ground truth is "japanese business law". The correct answer should be rated as 1 (bad).
# 0 0 japanese business law japanese business law
# {'A_wins': 0, 'B_wins': 29, 'tie': 62, 'A_score': 60, 'B_score': 285}
# 0 0 japanese business law japanese business law
# {'A_wins': 0, 'B_wins': 29, 'tie': 63, 'A_score': 60, 'B_score': 285}
# 0 0 korean general law korean general law
# {'A_wins': 0, 'B_wins': 29, 'tie': 64, 'A_score': 60, 'B_score': 285}
# Invalid json output: The provided answer is correct, and it aligns with the ground truth. The answer is well-structured and provides a clear classification of the given sentence. Therefore, I would rate the answer as a 5, indicating a very good answer.
#
# {"score": 5}
# 0 0 korean general law korean general law
# {'A_wins': 0, 'B_wins': 29, 'tie': 65, 'A_score': 60, 'B_score': 285}
# Error code: 429 - {'error_code': 'TOO_MANY_REQUESTS', 'message': {'en': "Thanks for loving our service. You've sent too many requests in a short time. Please try again later. For further help, contact console@upstage.ai"}}
# 6 10 korean business law japanese business law
# {'A_wins': 0, 'B_wins': 30, 'tie': 65, 'A_score': 66, 'B_score': 295}
# Invalid json output: The best answer is A.
#
# {"winner": "A"}
# 0 0 korean business law korean business law
# {'A_wins': 0, 'B_wins': 30, 'tie': 66, 'A_score': 66, 'B_score': 295}
# 0 0 korean general law korean business law
# {'A_wins': 0, 'B_wins': 30, 'tie': 67, 'A_score': 66, 'B_score': 295}
# 0 0 日本の一般法 japanese general law
# {'A_wins': 0, 'B_wins': 30, 'tie': 68, 'A_score': 66, 'B_score': 295}
# 0 0 japanese business law japanese business law
# {'A_wins': 0, 'B_wins': 30, 'tie': 69, 'A_score': 66, 'B_score': 295}
# Invalid json output: Based on the given prompt and input, the user is asking about the maximum number of days of paid leave that an employee can take in any one year, which is related to employment laws. The ground truth indicates that the answer should be classified as Japanese business law.
#
# Therefore, the better answer is:
# {"winner": "A"}
# 0 0 korean general law japanese business law
# {'A_wins': 0, 'B_wins': 30, 'tie': 70, 'A_score': 66, 'B_score': 295}
# 0 0 korean business law korean business law
# {'A_wins': 0, 'B_wins': 30, 'tie': 71, 'A_score': 66, 'B_score': 295}
# 2 10 korean general law korean business law
# {'A_wins': 0, 'B_wins': 31, 'tie': 71, 'A_score': 68, 'B_score': 305}
# 0 0 korean general law korean general law
# {'A_wins': 0, 'B_wins': 31, 'tie': 72, 'A_score': 68, 'B_score': 305}
# 0 0 日本の一般法 japanese general law
# {'A_wins': 0, 'B_wins': 31, 'tie': 73, 'A_score': 68, 'B_score': 305}
# 0 0 한국 일반법 korean general law
# {'A_wins': 0, 'B_wins': 31, 'tie': 74, 'A_score': 68, 'B_score': 305}
# 0 0 korean business law korean business law
# {'A_wins': 0, 'B_wins': 31, 'tie': 75, 'A_score': 68, 'B_score': 305}
# Error code: 429 - {'error_code': 'TOO_MANY_REQUESTS', 'message': {'en': "Thanks for loving our service. You've sent too many requests in a short time. Please try again later. For further help, contact console@upstage.ai"}}
# 0 0 korean general law korean business law
# {'A_wins': 0, 'B_wins': 31, 'tie': 76, 'A_score': 68, 'B_score': 305}
# 0 0 korean general law korean general law
# {'A_wins': 0, 'B_wins': 31, 'tie': 77, 'A_score': 68, 'B_score': 305}
# Error code: 429 - {'error_code': 'TOO_MANY_REQUESTS', 'message': {'en': "Thanks for loving our service. You've sent too many requests in a short time. Please try again later. For further help, contact console@upstage.ai"}}
# 2 10 korean general law korean business law
# {'A_wins': 0, 'B_wins': 32, 'tie': 77, 'A_score': 70, 'B_score': 315}
# 0 0 korean business law korean business law
# {'A_wins': 0, 'B_wins': 32, 'tie': 78, 'A_score': 70, 'B_score': 315}
# Error code: 429 - {'error_code': 'TOO_MANY_REQUESTS', 'message': {'en': "Thanks for loving our service. You've sent too many requests in a short time. Please try again later. For further help, contact console@upstage.ai"}}
# Invalid json output: The score for the provided answer is 5.
# 0 0 korean business law korean business law
# {'A_wins': 0, 'B_wins': 32, 'tie': 79, 'A_score': 70, 'B_score': 315}
# 0 0 日本一般法 japanese general law
# {'A_wins': 0, 'B_wins': 32, 'tie': 80, 'A_score': 70, 'B_score': 315}
# 2 10 japanese business law japanese general law
# {'A_wins': 0, 'B_wins': 33, 'tie': 80, 'A_score': 72, 'B_score': 325}
# Invalid json output: The provided answer is correct as it falls under the category of "japanese business law". Therefore, I would rate the answer as a 5, indicating a very good answer.
#
# {"score": 5}
# 0 0 japanese business law japanese business law
# {'A_wins': 0, 'B_wins': 33, 'tie': 81, 'A_score': 72, 'B_score': 325}
# 2 10 korean general law korean business law
# {'A_wins': 0, 'B_wins': 34, 'tie': 81, 'A_score': 74, 'B_score': 335}
# Invalid json output: The provided answer is correct, according to the ground truth. Therefore, I rate the answer as a 5, indicating a very good answer.
#
# {"score": 5}
# 0 0 korean general law korean general law
# {'A_wins': 0, 'B_wins': 34, 'tie': 82, 'A_score': 74, 'B_score': 335}
# Invalid json output: The provided answer is accurate and corresponds to the ground truth, which is "japanese general law". The answer is clear and concise. Therefore, I rate the answer as 5.
#
# {"score": 5}
# 2 10  Japanese Business Law japanese general law
# {'A_wins': 0, 'B_wins': 35, 'tie': 82, 'A_score': 76, 'B_score': 345}
# 0 0 korean business law korean business law
# {'A_wins': 0, 'B_wins': 35, 'tie': 83, 'A_score': 76, 'B_score': 345}
# 0 0 korean general law korean general law
# {'A_wins': 0, 'B_wins': 35, 'tie': 84, 'A_score': 76, 'B_score': 345}
# 2 10 korean general law japanese business law
# {'A_wins': 0, 'B_wins': 36, 'tie': 84, 'A_score': 78, 'B_score': 355}
# Invalid json output: The provided answer is accurate and matches the ground truth. Therefore, I rate the answer as a 5 on the Likert scale.
#
# {"score": 5}
# 0 0 japanese business law japanese business law
# {'A_wins': 0, 'B_wins': 36, 'tie': 85, 'A_score': 78, 'B_score': 355}
# 0 0 日本の一般法 japanese general law
# {'A_wins': 0, 'B_wins': 36, 'tie': 86, 'A_score': 78, 'B_score': 355}
# 0 0 日本の一般法 japanese general law
# {'A_wins': 0, 'B_wins': 36, 'tie': 87, 'A_score': 78, 'B_score': 355}
# 0 0 korean general law korean general law
# {'A_wins': 0, 'B_wins': 36, 'tie': 88, 'A_score': 78, 'B_score': 355}
# 0 0 한국 일반법 korean general law
# {'A_wins': 0, 'B_wins': 36, 'tie': 89, 'A_score': 78, 'B_score': 355}
# 0 0 japanese business law japanese business law
# {'A_wins': 0, 'B_wins': 36, 'tie': 90, 'A_score': 78, 'B_score': 355}
# 0 0 korean general law korean general law
# {'A_wins': 0, 'B_wins': 36, 'tie': 91, 'A_score': 78, 'B_score': 355}
# 2 6 korean general law korean business law
# {'A_wins': 0, 'B_wins': 37, 'tie': 91, 'A_score': 80, 'B_score': 361}
# 2 10 公益信託の引受けの許可を申請する際に必要な書類は何ですか？ japanese general law
# {'A_wins': 0, 'B_wins': 38, 'tie': 91, 'A_score': 82, 'B_score': 371}
# 0 0 korean general law korean general law
# {'A_wins': 0, 'B_wins': 38, 'tie': 92, 'A_score': 82, 'B_score': 371}
# 0 0 japanese business law japanese business law
# {'A_wins': 0, 'B_wins': 38, 'tie': 93, 'A_score': 82, 'B_score': 371}
# 2 10 korean business law japanese business law
# {'A_wins': 0, 'B_wins': 39, 'tie': 93, 'A_score': 84, 'B_score': 381}
# 2 10 korean general law korean business law
# {'A_wins': 0, 'B_wins': 40, 'tie': 93, 'A_score': 86, 'B_score': 391}
# 0 0 korean business law korean business law
# {'A_wins': 0, 'B_wins': 40, 'tie': 94, 'A_score': 86, 'B_score': 391}
# 4 8 korean general law korean business law
# {'A_wins': 0, 'B_wins': 41, 'tie': 94, 'A_score': 90, 'B_score': 399}
# 0 0 日本の一般法 japanese general law
# {'A_wins': 0, 'B_wins': 41, 'tie': 95, 'A_score': 90, 'B_score': 399}
# 0 0 japanese business law japanese business law
# {'A_wins': 0, 'B_wins': 41, 'tie': 96, 'A_score': 90, 'B_score': 399}
# 2 10 korean business law japanese business law
# {'A_wins': 0, 'B_wins': 42, 'tie': 96, 'A_score': 92, 'B_score': 409}
# 0 0 korean general law korean business law
# {'A_wins': 0, 'B_wins': 42, 'tie': 97, 'A_score': 92, 'B_score': 409}
# 2 10 korean business law japanese business law
# {'A_wins': 0, 'B_wins': 43, 'tie': 97, 'A_score': 94, 'B_score': 419}
# 0 0 日本の一般法 japanese general law
# {'A_wins': 0, 'B_wins': 43, 'tie': 98, 'A_score': 94, 'B_score': 419}
# 0 0 korean general law korean general law
# {'A_wins': 0, 'B_wins': 43, 'tie': 99, 'A_score': 94, 'B_score': 419}
# 2 10 korean business law japanese business law
# {'A_wins': 0, 'B_wins': 44, 'tie': 99, 'A_score': 96, 'B_score': 429}
# 0 0 korean general law korean business law
# {'A_wins': 0, 'B_wins': 44, 'tie': 100, 'A_score': 96, 'B_score': 429}
# 2 10 korean business law japanese business law
# {'A_wins': 0, 'B_wins': 45, 'tie': 100, 'A_score': 98, 'B_score': 439}
# 0 0 korean general law korean business law
# {'A_wins': 0, 'B_wins': 45, 'tie': 101, 'A_score': 98, 'B_score': 439}
# 0 0 korean general law korean business law
# {'A_wins': 0, 'B_wins': 45, 'tie': 102, 'A_score': 98, 'B_score': 439}
# 0 0 日本の一般法 japanese general law
# {'A_wins': 0, 'B_wins': 45, 'tie': 103, 'A_score': 98, 'B_score': 439}
# 0 0 한국 일반법 korean general law
# {'A_wins': 0, 'B_wins': 45, 'tie': 104, 'A_score': 98, 'B_score': 439}
# 0 0 korean general law korean general law
# {'A_wins': 0, 'B_wins': 45, 'tie': 105, 'A_score': 98, 'B_score': 439}
# 0 0 korean general law korean business law
# {'A_wins': 0, 'B_wins': 45, 'tie': 106, 'A_score': 98, 'B_score': 439}
# 0 0 korean business law korean business law
# {'A_wins': 0, 'B_wins': 45, 'tie': 107, 'A_score': 98, 'B_score': 439}
# 2 10 korean general law korean business law
# {'A_wins': 0, 'B_wins': 46, 'tie': 107, 'A_score': 100, 'B_score': 449}
# 0 0  일본 일반법 japanese general law
# {'A_wins': 0, 'B_wins': 46, 'tie': 108, 'A_score': 100, 'B_score': 449}
# 0 0 korean general law korean general law
# {'A_wins': 0, 'B_wins': 46, 'tie': 109, 'A_score': 100, 'B_score': 449}
# 0 0 korean general law korean general law
# {'A_wins': 0, 'B_wins': 46, 'tie': 110, 'A_score': 100, 'B_score': 449}
# 2 10 korean general law korean business law
# {'A_wins': 0, 'B_wins': 47, 'tie': 110, 'A_score': 102, 'B_score': 459}
# 2 10 korean business law japanese business law
# {'A_wins': 0, 'B_wins': 48, 'tie': 110, 'A_score': 104, 'B_score': 469}
# 0 0 korean business law korean business law
# {'A_wins': 0, 'B_wins': 48, 'tie': 111, 'A_score': 104, 'B_score': 469}
# 2 10 korean business law japanese business law
# {'A_wins': 0, 'B_wins': 49, 'tie': 111, 'A_score': 106, 'B_score': 479}
# 2 10 korean general law korean business law
# {'A_wins': 0, 'B_wins': 50, 'tie': 111, 'A_score': 108, 'B_score': 489}
# 0 0 korean general law korean business law
# {'A_wins': 0, 'B_wins': 50, 'tie': 112, 'A_score': 108, 'B_score': 489}
# 0 0 korean general law korean general law
# {'A_wins': 0, 'B_wins': 50, 'tie': 113, 'A_score': 108, 'B_score': 489}
# 0 0 japanese general law japanese general law
# {'A_wins': 0, 'B_wins': 50, 'tie': 114, 'A_score': 108, 'B_score': 489}
# 2 10 korean business law japanese business law
# {'A_wins': 0, 'B_wins': 51, 'tie': 114, 'A_score': 110, 'B_score': 499}
# 4 10 japanese business law japanese general law
# {'A_wins': 0, 'B_wins': 52, 'tie': 114, 'A_score': 114, 'B_score': 509}
# 0 0 japanese business law japanese business law
# {'A_wins': 0, 'B_wins': 52, 'tie': 115, 'A_score': 114, 'B_score': 509}
# 0 0 日本の一般法 japanese general law
# {'A_wins': 0, 'B_wins': 52, 'tie': 116, 'A_score': 114, 'B_score': 509}
# 0 0 korean general law korean general law
# {'A_wins': 0, 'B_wins': 52, 'tie': 117, 'A_score': 114, 'B_score': 509}
# 0 0 japanese business law japanese business law
# {'A_wins': 0, 'B_wins': 52, 'tie': 118, 'A_score': 114, 'B_score': 509}
# 0 0 일본の一般法 japanese general law
# {'A_wins': 0, 'B_wins': 52, 'tie': 119, 'A_score': 114, 'B_score': 509}
# 3 8 korean general law korean business law
# {'A_wins': 0, 'B_wins': 53, 'tie': 119, 'A_score': 117, 'B_score': 517}
# 2 10 korean business law japanese business law
# {'A_wins': 0, 'B_wins': 54, 'tie': 119, 'A_score': 119, 'B_score': 527}
# 0 0 japanese business law japanese business law
# {'A_wins': 0, 'B_wins': 54, 'tie': 120, 'A_score': 119, 'B_score': 527}
# 0 0 korean general law korean general law
# {'A_wins': 0, 'B_wins': 54, 'tie': 121, 'A_score': 119, 'B_score': 527}
# 0 0 일본 일반법 japanese general law
# {'A_wins': 0, 'B_wins': 54, 'tie': 122, 'A_score': 119, 'B_score': 527}
# 3 10 korean general law korean business law
# {'A_wins': 0, 'B_wins': 55, 'tie': 122, 'A_score': 122, 'B_score': 537}
# 0 0 日本の一般法 japanese general law
# {'A_wins': 0, 'B_wins': 55, 'tie': 123, 'A_score': 122, 'B_score': 537}
# 0 0 korean general law korean business law
# {'A_wins': 0, 'B_wins': 55, 'tie': 124, 'A_score': 122, 'B_score': 537}
# 2 10 japanese general law japanese business law
# {'A_wins': 0, 'B_wins': 56, 'tie': 124, 'A_score': 124, 'B_score': 547}
# 0 0 日本の一般法 japanese general law
# {'A_wins': 0, 'B_wins': 56, 'tie': 125, 'A_score': 124, 'B_score': 547}
# 0 0 korean business law korean business law
# {'A_wins': 0, 'B_wins': 56, 'tie': 126, 'A_score': 124, 'B_score': 547}
# 0 0 japanese business law japanese business law
# {'A_wins': 0, 'B_wins': 56, 'tie': 127, 'A_score': 124, 'B_score': 547}
# 0 0  일본一般法 japanese general law
# {'A_wins': 0, 'B_wins': 56, 'tie': 128, 'A_score': 124, 'B_score': 547}
# 0 0 korean business law korean business law
# {'A_wins': 0, 'B_wins': 56, 'tie': 129, 'A_score': 124, 'B_score': 547}
# 2 10 korean general law korean business law
# {'A_wins': 0, 'B_wins': 57, 'tie': 129, 'A_score': 126, 'B_score': 557}
# 2 10 korean business law japanese business law
# {'A_wins': 0, 'B_wins': 58, 'tie': 129, 'A_score': 128, 'B_score': 567}
# 2 10 korean general law japanese business law
# {'A_wins': 0, 'B_wins': 59, 'tie': 129, 'A_score': 130, 'B_score': 577}
# 0 0 japanese general law japanese general law
# {'A_wins': 0, 'B_wins': 59, 'tie': 130, 'A_score': 130, 'B_score': 577}
# 2 10  Japanese business law japanese general law
# {'A_wins': 0, 'B_wins': 60, 'tie': 130, 'A_score': 132, 'B_score': 587}
# 0 0 korean business law korean business law
# {'A_wins': 0, 'B_wins': 60, 'tie': 131, 'A_score': 132, 'B_score': 587}
# 0 0 korean general law korean general law
# {'A_wins': 0, 'B_wins': 60, 'tie': 132, 'A_score': 132, 'B_score': 587}
# 0 0 일본の一般法 japanese general law
# {'A_wins': 0, 'B_wins': 60, 'tie': 133, 'A_score': 132, 'B_score': 587}
# 0 0 korean general law korean general law
# {'A_wins': 0, 'B_wins': 60, 'tie': 134, 'A_score': 132, 'B_score': 587}
# 0 0 korean general law korean general law
# {'A_wins': 0, 'B_wins': 60, 'tie': 135, 'A_score': 132, 'B_score': 587}
# 0 0 한국 일반법 korean general law
# {'A_wins': 0, 'B_wins': 60, 'tie': 136, 'A_score': 132, 'B_score': 587}
# 0 0 일본 일반법 japanese general law
# {'A_wins': 0, 'B_wins': 60, 'tie': 137, 'A_score': 132, 'B_score': 587}
# Invalid json output: Based on the prompt and the ground truth, I would rate the provided answer as a 5, indicating a very good answer. The question is asking about the significance of Yongo in Korean society and business, which falls under the category of Korean business law. The AI assistant correctly identified this and provided the correct classification.
# 0 0 korean business law korean business law
# {'A_wins': 0, 'B_wins': 60, 'tie': 138, 'A_score': 132, 'B_score': 587}
# 0 0 korean business law korean business law
# {'A_wins': 0, 'B_wins': 60, 'tie': 139, 'A_score': 132, 'B_score': 587}
# 0 0 japanese business law japanese business law
# {'A_wins': 0, 'B_wins': 60, 'tie': 140, 'A_score': 132, 'B_score': 587}

# %%
print(win_results)
# Out:
# {'A_wins': 0, 'B_wins': 60, 'tie': 140, 'A_score': 132, 'B_score': 587}
