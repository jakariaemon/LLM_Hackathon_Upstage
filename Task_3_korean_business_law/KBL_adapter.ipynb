# %%
# !pip install -q predibase datasets
# Out:
# & was unexpected at this time.
# The value specified in an AutoRun registry key could not be parsed.
# WARNING: typer 0.12.3 does not provide the extra 'all'
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gradio 4.37.2 requires urllib3~=2.0, but you have urllib3 1.26.12 which is incompatible.

# %%
import warnings

warnings.filterwarnings("ignore")

# %%
from datasets import load_dataset
import csv

def hfdataset_to_csv(datalist: list, csv_file_name, max=-1):
  template = {
        "prompt":
        """<|im_start|>system\nYou are an bunisee law expert. Based on the given question, generate a single line answer concisely.  <|im_end|>
<|im_start|>Question\n {content}
<|im_start|>Answer\n""",
        "completion": "{headline}<|im_end|>",
        "split": "train"}


  with open(csv_file_name, 'w', newline='') as csvfile:
    fieldnames = template.keys()
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    for i, d in enumerate(datalist):
      if i >= max:
        break
      row = {
          "prompt": template["prompt"].format(content=d["Question"]),
          "completion": template["completion"].format(headline=d["Answer"]),
          "split": "train"
      }
      writer.writerow(row)

# %%
def validate_data_csv(csv_file_name):
  """ Make sure it has prompt, completion, and split with all values """
  with open(csv_file_name, 'r') as f:
    reader = csv.DictReader(f)
    for row in reader:
      assert row['prompt']
      assert row['completion']
      assert row['split']

  return True

# %%
from tokenizers import Tokenizer
tokenizer = Tokenizer.from_pretrained("upstage/solar-1-mini-tokenizer")

def compute_cost(csv_file_name, price_per_million_tokens=0.5):
  """ Compute the cost of the dataset """

  total_num_of_tokens = 0
  with open(csv_file_name, 'r') as f:
    reader = csv.DictReader(f)
    # get all values
    values = [row['completion']+ " " + row['prompt'] for row in reader]
    for value in values:
      # tokenize
      enc = tokenizer.encode(value)
      num_of_tokens = len(enc.tokens)
      total_num_of_tokens += num_of_tokens


  return total_num_of_tokens / 1000000 * price_per_million_tokens

# %%
from datasets import load_dataset, Dataset
from sklearn.model_selection import train_test_split

# Load the dataset
hfdataset = load_dataset("csv", data_files="KBL_dataset.csv")
train_hfdataset = hfdataset["train"]
print(train_hfdataset)
# Convert the dataset to a pandas DataFrame for easier manipulation
train_df = train_hfdataset.to_pandas()

# Split the train dataset into 80% train and 20% test
train_split, test_split = train_test_split(train_df, test_size=0.1, random_state=42)

train_split.reset_index(drop=True, inplace=True)
test_split.reset_index(drop=True, inplace=True)

# Convert back to the Hugging Face Dataset format
train_dataset = Dataset.from_pandas(train_split)
test_dataset = Dataset.from_pandas(test_split)

# Print the sizes of the new datasets
print(f"Train dataset size: {len(train_dataset)}")
print(f"Test dataset size: {len(test_dataset)}")
print(train_dataset)
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Dataset({
#     features: ['Question', 'Answer'],
#     num_rows: 1468
# })
# Train dataset size: 1321
# Test dataset size: 147
# Dataset({
#     features: ['Question', 'Answer'],
#     num_rows: 1321
# })

# %%
dataset_name = "NMT_train_dataset"
csv_file_name = f"{dataset_name}.csv"
try:
  pb_dataset = pb.datasets.get(dataset_name)
  print(f"Dataset found: {pb_dataset}")
except RuntimeError:
  print("Dataset not found, creating...")

  hfdataset_to_csv(train_dataset, csv_file_name, max=1321)

  print(f"Dataset Validation: {validate_data_csv(csv_file_name)}")
  print(f"One step FT Cost: {compute_cost(csv_file_name)} USD")

  #print("Uploading daatset...")
  pb_dataset = pb.datasets.from_file(csv_file_name, name=dataset_name)
# Out:
# Dataset not found, creating...
# Dataset Validation: True
# One step FT Cost: 0.0592745 USD

# %%
repo_name = "KBL-01"
repo = pb.repos.create(name=repo_name, description="Upstage_Hackathon_KBL_Adapter", exists_ok=True)
print(repo)
# Out:
# uuid='3857a37e-6853-45e8-bc2a-b90fe6233237' name='KBL-01' description='Upstage_Hackathon_KBL_Adapter'

# %%
adapter = pb.adapters.create(
    config=FinetuningConfig(
        base_model="solar-1-mini-chat-240612",
        epochs=3, # default: 3
        rank=16, # default: 16
    ),
    dataset=pb_dataset, # Also accepts the dataset name as a string
    repo=repo,
    description="initial model with defaults"
)
# Out:
# Successfully requested finetuning of solar-1-mini-chat-240612 as `KBL-01/1`. (Job UUID: 6b60911e-8b86-46f1-a785-6e01b6a55a93).
#
# Watching progress of finetuning job 6b60911e-8b86-46f1-a785-6e01b6a55a93. This call will block until the job has finished. Canceling or terminating this call will NOT cancel or terminate the job itself.
#
# Job is starting. Total queue time: 0:00:45
# Waiting to receive training metrics...
#
# ┌────────────┬────────────┬─────────────────┐
# │ checkpoint │ train_loss │ validation_loss │
# ├────────────┼────────────┼─────────────────┤
# │     1      │   1.4888   │        --       │
# │     2      │   1.5464   │        --       │
# └────────────┴────────────┴─────────────────┘

# %%
adapter
# Out:
# Adapter(repo='KBL-01', tag=1, archived=False, base_model='solar-1-mini-chat-240612', description='initial model with defaults', artifact_path='6b60911e-8b86-46f1-a785-6e01b6a55a93/9dbcddf4fb634382897ebba29d8f59dd/artifacts/model/model_weights', finetuning_error=None, finetuning_job_uuid='6b60911e-8b86-46f1-a785-6e01b6a55a93')

# %%
adapter_id = adapter.repo + "/" + str(adapter.tag)
adapter_id
# Out:
# 'KBL-01/1'

# %%
input_prompt="""
<|im_start|>system\nYou are an bunisee law expert. Based on the given question, generate a single line answer concisely..<|im_end|>
<|im_start|>Question
What is the website address for the Korean branch of PwC? <|im_end|>
<|im_start|>Answer
"""

# %%
# CURL test
import requests
import json

url = "https://serving.app.predibase.com/7ea6d0/deployments/v2/llms/solar-1-mini-chat-240612/generate"


payload = {
    "inputs": input_prompt,
    "parameters": {
        "adapter_id": adapter_id,
        "adapter_source": "pbase",
        "max_new_tokens": 60,
        "temperature": 0.1
    }
}

headers = {
    "Content-Type": "application/json",
    "Authorization": f"Bearer {api_token}"
}

response = requests.post(url, data=json.dumps(payload), headers=headers)

print(response.text)
# Out:
# {"generated_text":"www.pwc.com/kr"}

# %%
# !pip -q install langchain langchain-upstage solar-as-judge
# Out:
# & was unexpected at this time.
# The value specified in an AutoRun registry key could not be parsed.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\emon\anaconda3\Lib\site-packages\~ydantic_core'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gradio 4.37.2 requires urllib3~=2.0, but you have urllib3 1.26.12 which is incompatible.

# %%
lorax_client = pb.deployments.client("solar-1-mini-chat-240612")

# %%
# Create test dataset
test_csv_file_name = f"KBL_test_dataset"
hfdataset_to_csv(test_dataset, test_csv_file_name, max=147)

win_results = {"A_wins":0, "B_wins": 0, "tie": 0,  "A_score": 0, "B_score": 0}
with open(test_csv_file_name, 'r') as f:
  reader = csv.DictReader(f)
  for row in reader:
    prompt = row['prompt']
    ground_truth = row['completion']
    A_answer = lorax_client.generate(prompt, max_new_tokens=10).generated_text
    B_answer = lorax_client.generate(prompt, adapter_id=adapter_id, max_new_tokens=1000).generated_text

    A_score, B_score = saj.judge(prompt, A_answer, B_answer, ground_truth)
    print( A_score, B_score, A_answer, B_answer)
    win_results["A_score"] += A_score
    win_results["B_score"] += B_score
    if A_score > B_score:
      win_results["A_wins"] += 1
    elif B_score > A_score:
      win_results["B_wins"] += 1
    else:
      win_results["tie"] += 1
    print(win_results)
# Out:
# 0 0 Over the years, Korean products have significantly improved in The quality and popularity of Korean products have significantly improved over the years, with Korean products now being highly popular and sought after in the global market.
# {'A_wins': 0, 'B_wins': 0, 'tie': 1, 'A_score': 0, 'B_score': 0}
# 8 2 Fennec Shand Jang
# {'A_wins': 1, 'B_wins': 0, 'tie': 1, 'A_score': 8, 'B_score': 2}
# 0 0 Yes, there are regulations for advertising certain types of Yes, there are regulations for advertising certain types of products in Korea. For example, advertising for alcoholic beverages is prohibited on television between 6:00 a.m. and 8:00 p.m. and on radio between 6:00 a.m. and 9:00 a.m. and 1:00 p.m. to 5:00 p.m.
# {'A_wins': 1, 'B_wins': 0, 'tie': 2, 'A_score': 8, 'B_score': 2}
# 0 0 The location of PwC's office in PwC Poland
# {'A_wins': 1, 'B_wins': 0, 'tie': 3, 'A_score': 8, 'B_score': 2}
# 10 8 Yes, foreigners are allowed to acquire land in Foreigners are allowed to acquire land in Korea, but they must obtain a permit from the competent government authority.
# {'A_wins': 2, 'B_wins': 0, 'tie': 3, 'A_score': 18, 'B_score': 10}
# 0 0 Yes, global taxation is applied to non- Yes, global taxation is applied to non-residents who have a place of business in Korea or earn income from real estate located in Korea.
# {'A_wins': 2, 'B_wins': 0, 'tie': 4, 'A_score': 18, 'B_score': 10}
# 2 10 Transfer pricing forms, country-by-country ( The three primary types of transfer pricing forms that taxpayers engaging in transactions with overseas related parties must submit when filing their tax returns under the LCITA are Form 1, Form 2, and Form 3.
# {'A_wins': 2, 'B_wins': 1, 'tie': 4, 'A_score': 20, 'B_score': 20}
# 0 0 The total percentage of imports from the top four countries 40.5%
# {'A_wins': 2, 'B_wins': 1, 'tie': 5, 'A_score': 20, 'B_score': 20}
# 10 5 The consequences for engaging in backdoor listing can include Engaging in backdoor listing can result in a fine of up to KRW100 million.
# {'A_wins': 3, 'B_wins': 1, 'tie': 5, 'A_score': 30, 'B_score': 25}
# 0 0 PwC Japan PwC Japan
# {'A_wins': 3, 'B_wins': 1, 'tie': 6, 'A_score': 30, 'B_score': 25}
# 2 10 You-il Lee works at the University of California You-il Lee works at the University of South Australia.
# {'A_wins': 3, 'B_wins': 2, 'tie': 6, 'A_score': 32, 'B_score': 35}
# 0 0 The return of conservative polity in Korea led to The return of conservative polity in 1997 led to a re-emergence of the state's role in the economy and society, with the state taking a more active role in managing the economy and society.
# {'A_wins': 3, 'B_wins': 2, 'tie': 7, 'A_score': 32, 'B_score': 35}
# 10 3 The 11.1 table focuses on the The 11.1 table focuses on the export of goods to Korea.
# {'A_wins': 4, 'B_wins': 2, 'tie': 7, 'A_score': 42, 'B_score': 38}
# 0 0 Accounting records, excluding accounting slips, Accounting records, excluding accounting slips, are required to be retained for five years.
# {'A_wins': 4, 'B_wins': 2, 'tie': 8, 'A_score': 42, 'B_score': 38}
# 2 6 Foreigners can do business in Korea like native Kore Foreigners with F-2 and F-5 visa statuses can do business in Korea like native Koreans.
# {'A_wins': 4, 'B_wins': 3, 'tie': 8, 'A_score': 44, 'B_score': 44}
# 0 0 Support from the home organization and a positive attitude towards The two pre-departure factors that might aid later adjustment for expatriates moving to Korea are a high level of cultural knowledge and a high level of language proficiency.
# {'A_wins': 4, 'B_wins': 3, 'tie': 9, 'A_score': 44, 'B_score': 44}
# 10 7 The focus of Chapter 5 in the book is Chapter 5 focuses on the Korean business environment and its unique features, including the role of the government, the importance of relationships, and the impact of Confucianism on business practices.
# {'A_wins': 5, 'B_wins': 3, 'tie': 9, 'A_score': 54, 'B_score': 51}
# 0 0 Foreign companies need to register their business in Korea and Foreign companies need to understand the Korean market and its unique characteristics before entering. They should also be aware of the challenges they may face, such as language barriers, cultural differences, and regulatory hurdles.
# {'A_wins': 5, 'B_wins': 3, 'tie': 10, 'A_score': 54, 'B_score': 51}
# 9 6 The current state of labor shortages in Korea is Korea is experiencing a severe labor shortage, with the unemployment rate at a record low of 3.6% in 2018.
# {'A_wins': 6, 'B_wins': 3, 'tie': 10, 'A_score': 63, 'B_score': 57}
# 0 0 To use Korean e-commerce platforms for exporting A business registration certificate, a tax registration certificate, and a foreign trade license are required to use Korean e-commerce platforms for exporting consumer goods.
# {'A_wins': 6, 'B_wins': 3, 'tie': 11, 'A_score': 63, 'B_score': 57}
# 2 6 The taxable value of imported goods for customs duties The taxable value of imported goods for customs duties, individual excise tax, and liquor tax is the price of the imported goods plus the cost of transportation and insurance.
# {'A_wins': 6, 'B_wins': 4, 'tie': 11, 'A_score': 65, 'B_score': 63}
# 6 10 The arm's-length principle is a method The arm's-length principle is used to determine the proper level of prices charged in transactions between Korean resident corporations and overseas related parties.
# {'A_wins': 6, 'B_wins': 5, 'tie': 11, 'A_score': 71, 'B_score': 73}
# 0 0 Jikgu purchase is a term used in the Consumers who often engage in jikgu purchase are those who are familiar with the product and have a high level of trust in the brand.
# {'A_wins': 6, 'B_wins': 5, 'tie': 12, 'A_score': 71, 'B_score': 73}
# 0 0 The gender distribution of the workforce in Korea is The gender distribution of the workforce in Korea is 69.5% male and 30.5% female.
# {'A_wins': 6, 'B_wins': 5, 'tie': 13, 'A_score': 71, 'B_score': 73}
# 8 2 "Jikgu" refers to the act of Jikgu refers to the Korean tax authorities.
# {'A_wins': 7, 'B_wins': 5, 'tie': 13, 'A_score': 79, 'B_score': 75}
# 7 2 In 2017, the favorite brand Samsung
# {'A_wins': 8, 'B_wins': 5, 'tie': 13, 'A_score': 86, 'B_score': 77}
# 6 9 South Korea's economy has evolved from a predomin South Korea's economy has experienced significant growth and transformation since the 1960s, with the country becoming one of the world's leading exporters and a major player in the global economy. The country has diversified its industries and developed strong capabilities in sectors such as electronics, automobiles, and shipbuilding.
# {'A_wins': 8, 'B_wins': 6, 'tie': 13, 'A_score': 92, 'B_score': 86}
# 6 2 The 12.2 table provides information on The 12.2 table shows the number of foreigners in Korea by nationality.
# {'A_wins': 9, 'B_wins': 6, 'tie': 13, 'A_score': 98, 'B_score': 88}
# 0 0 UNCTAD facilitates technology transfer by providing UNCTAD plays a role in technology transfer by providing a platform for developing countries to negotiate technology transfer agreements with developed countries.
# {'A_wins': 9, 'B_wins': 6, 'tie': 14, 'A_score': 98, 'B_score': 88}
# 0 0 The requirements for importing items into Korea include obtaining Importing items into Korea requires a valid import permit, which is issued by the Ministry of Trade, Industry, and Energy (MOTIE) or the Ministry of Food and Drug Safety (MFDS). The permit is required for items that are subject to import restrictions or prohibitions.
# {'A_wins': 9, 'B_wins': 6, 'tie': 15, 'A_score': 98, 'B_score': 88}
# 0 0 Language barriers, cultural differences, regulatory compliance, competition Both Korean and foreign companies face challenges in the Korean market, including the need to adapt to the local business environment and regulations, as well as competition from other companies.
# {'A_wins': 9, 'B_wins': 6, 'tie': 16, 'A_score': 98, 'B_score': 88}
# 0 0 From 1970 to 20 The main export items of Korea from 1970 to 2009 are not provided in the information.
# {'A_wins': 9, 'B_wins': 6, 'tie': 17, 'A_score': 98, 'B_score': 88}
# 0 0 The top bidders of inbound M& The top bidders of inbound M&As in South Korea by value are the US, Japan, and Europe.
# {'A_wins': 9, 'B_wins': 6, 'tie': 18, 'A_score': 98, 'B_score': 88}
# 10 2 Liquidation income of Korea branches of foreign Liquidation income is taxed as ordinary income of the Korea branch of a foreign corporation.
# {'A_wins': 10, 'B_wins': 6, 'tie': 18, 'A_score': 108, 'B_score': 90}
# 3 6 Export behavior is influenced by factors such as market demand Export behavior is influenced by the size of the home market, the size of the foreign market, the cost of exporting, the distance to the foreign market, the degree of market openness, the degree of competition in the foreign market, and the degree of competition in the home market.
# {'A_wins': 10, 'B_wins': 7, 'tie': 18, 'A_score': 111, 'B_score': 96}
# 0 0 The Korean government guided and regulated private industries through The Korean government guided or regulated private industries by setting up a system of industrial policy that was designed to promote the development of key industries.
# {'A_wins': 10, 'B_wins': 7, 'tie': 19, 'A_score': 111, 'B_score': 96}
# 3 6 The least cost demanding and least risky method for The least cost demanding and least risky method for smaller businesses is to enter Korea through an exporting arrangement.
# {'A_wins': 10, 'B_wins': 8, 'tie': 19, 'A_score': 114, 'B_score': 102}
# 0 0 The article "Typology of Online Shoppers" The article "Typology of Online Shoppers" was published in the Journal of Retailing and Consumer Services.
# {'A_wins': 10, 'B_wins': 8, 'tie': 20, 'A_score': 114, 'B_score': 102}
# 0 0 The location of PwC's office in PwC Russia
# {'A_wins': 10, 'B_wins': 8, 'tie': 21, 'A_score': 114, 'B_score': 102}
# 6 10 The IMF prescribed several priorities and steps for The IMF prescribed three priorities and steps for Korea to take during the financial crisis: (1) restructuring the financial system, (2) restructuring the corporate sector, and (3) restructuring the public sector.
# {'A_wins': 10, 'B_wins': 9, 'tie': 21, 'A_score': 120, 'B_score': 112}
# 0 0 The Asian financial crisis in 1997 The financial crisis of 1997 undermined investment in the financial sector in Korea.
# {'A_wins': 10, 'B_wins': 9, 'tie': 22, 'A_score': 120, 'B_score': 112}
# 10 5 The main reason for the increase in South Korea' The main reason for the increase in South Korea's outbound M&As is the need to secure resources and technologies to expand their businesses.
# {'A_wins': 11, 'B_wins': 9, 'tie': 22, 'A_score': 130, 'B_score': 117}
# 2 6 49 trillion won USD10 billion was redirected to recapitalize the banking sector under Kim Dae-Jung's administration.
# {'A_wins': 11, 'B_wins': 10, 'tie': 22, 'A_score': 132, 'B_score': 123}
# 0 0 The Asian financial crisis led to significant changes in Korea The Asian financial crisis led to a re-evaluation of Korea's economic policies, particularly the need for a more balanced economic structure and a stronger financial system.
# {'A_wins': 11, 'B_wins': 10, 'tie': 23, 'A_score': 132, 'B_score': 123}
# Error code: 429 - {'error_code': 'TOO_MANY_REQUESTS', 'message': {'en': "Thanks for loving our service. You've sent too many requests in a short time. Please try again later. For further help, contact console@upstage.ai"}}
# 2 10 Korean Commercial Law does not specify a specific frequency for A book must be closed at least once a year.
# {'A_wins': 11, 'B_wins': 11, 'tie': 23, 'A_score': 134, 'B_score': 133}
# 0 0 Yes, a qualified foreign invested corporation can be ex Yes, a qualified foreign invested corporation can be exempt from customs duties, individual excise tax, and VAT on capital goods imported or contributed in-kind by a foreign investor.
# {'A_wins': 11, 'B_wins': 11, 'tie': 24, 'A_score': 134, 'B_score': 133}
# 0 0 Companies can leverage technology to improve their market Companies can leverage technology to improve their market access by using digital platforms to reach customers, automating processes to increase efficiency, and utilizing data analytics to gain insights into customer behavior and preferences.
# {'A_wins': 11, 'B_wins': 11, 'tie': 25, 'A_score': 134, 'B_score': 133}
# 3 6 Foreigners can do business in Korea by registering Foreigners can do business in Korea by establishing a company or by engaging in business activities as a non-resident.
# {'A_wins': 11, 'B_wins': 12, 'tie': 25, 'A_score': 137, 'B_score': 139}
# 0 0 The author of "The Future of Freedom" is Friedrich Hayek
# {'A_wins': 11, 'B_wins': 12, 'tie': 26, 'A_score': 137, 'B_score': 139}
# 2 6 The desire to experience a new culture and way of Another motivational factor for expatriates moving to Korea was the opportunity to learn a new language and culture.
# {'A_wins': 11, 'B_wins': 13, 'tie': 26, 'A_score': 139, 'B_score': 145}
# Error code: 429 - {'error_code': 'TOO_MANY_REQUESTS', 'message': {'en': "Thanks for loving our service. You've sent too many requests in a short time. Please try again later. For further help, contact console@upstage.ai"}}
# 0 0 Two companies are related parties under the LCIT Two companies are related parties if they are under common control or if they are under common control with a third company.
# {'A_wins': 11, 'B_wins': 13, 'tie': 27, 'A_score': 139, 'B_score': 145}
# 6 8 In Korea, employers have several retirement benefits options, Employers in Korea have the option to provide retirement benefits to their employees in the form of a pension plan or a retirement allowance.
# {'A_wins': 11, 'B_wins': 14, 'tie': 27, 'A_score': 145, 'B_score': 153}
# 0 0 The Emissions Trading Scheme (ETS The Emissions Trading Scheme (ETS) in South Korea became mandatory for certain installations and firms in 2015.
# {'A_wins': 11, 'B_wins': 14, 'tie': 28, 'A_score': 145, 'B_score': 153}
# 10 5 Korean companies ensure a strong alignment between top-level Korean companies ensure a strong alignment between top-level leadership and organizational behavior by having top-level leaders who are also the owners of the company.
# {'A_wins': 12, 'B_wins': 14, 'tie': 28, 'A_score': 155, 'B_score': 158}
# 0 0 To effectively navigate the Korean market and its unique cultural It is recommended for foreign companies to use a Korean advertising agency because they have a better understanding of the Korean market and can help create more effective advertising campaigns.
# {'A_wins': 12, 'B_wins': 14, 'tie': 29, 'A_score': 155, 'B_score': 158}
# 0 0 The goal of MNEs in Korea, as The goal of MNEs in Korea is to take advantage of the country's unique business environment, which has been shaped by the government's export-oriented industrialization policies and the emergence of world-class Korean firms in various industries.
# {'A_wins': 12, 'B_wins': 14, 'tie': 30, 'A_score': 155, 'B_score': 158}
# Invalid json output: The provided answer does not directly address the question of how foreign ownership ceilings and additional criteria are released and updated. Instead, it provides a general statement about the subject. Therefore, I would rate this answer as 1, indicating a bad answer.
# 6 4 Foreign ownership ceilings and additional criteria are typically Foreign ownership ceilings and additional criteria are released and updated by the Ministry of Strategy and Finance and the Financial Services Commission.
# {'A_wins': 13, 'B_wins': 14, 'tie': 30, 'A_score': 161, 'B_score': 162}
# Invalid json output: Evaluation: 2
#
# The answer provided does not accurately address the question. The question asks for the name of the study, not a summary of the study's content. A more accurate answer would be "Hemmert et al. (2015)" as it is the ground truth.
# 10 4 "The Impact of Managerial Autonomy on the The study is "Managerial autonomy in foreign-owned R&D labs in Korea: A study of foreign-owned R&D labs in Korea."
# {'A_wins': 14, 'B_wins': 14, 'tie': 30, 'A_score': 171, 'B_score': 166}
# 0 0 Fabian Jintae Froese's Fabian Jintae Froese's research interests include international business, globalization, and Asian business.
# {'A_wins': 14, 'B_wins': 14, 'tie': 31, 'A_score': 171, 'B_score': 166}
# 10 6 The strongest growth-enabling factor for foreign- The strongest growth-enabling factor for foreign-owned R&D labs in Korea is the availability of highly skilled and educated labor.
# {'A_wins': 15, 'B_wins': 14, 'tie': 31, 'A_score': 181, 'B_score': 172}
# Error code: 429 - {'error_code': 'TOO_MANY_REQUESTS', 'message': {'en': "Thanks for loving our service. You've sent too many requests in a short time. Please try again later. For further help, contact console@upstage.ai"}}
# 6 8 By offering unique products or services that cater to the Most foreign companies can distinguish themselves in the Korean market by offering a unique product or service that is not available locally.
# {'A_wins': 15, 'B_wins': 15, 'tie': 31, 'A_score': 187, 'B_score': 180}
# 0 0 Yes, taxation materials, including tax information and Yes, taxation materials, such as tax information and tax consultation cases for foreigners, are available in English on the National Tax Service website.
# {'A_wins': 15, 'B_wins': 15, 'tie': 32, 'A_score': 187, 'B_score': 180}
# 0 0 "Saejeongbyeol" The new term in Korean that refers to value consumption is "suseolgyeong gyeol."
# {'A_wins': 15, 'B_wins': 15, 'tie': 33, 'A_score': 187, 'B_score': 180}
# 0 0 The advertising expenditure in South Korea by medium is The advertising expenditure in South Korea by medium is as follows:
# {'A_wins': 15, 'B_wins': 15, 'tie': 34, 'A_score': 187, 'B_score': 180}
# 6 9 Implementing comprehensive immigration policies, improving language and cultural To address the challenges of managing foreign workers in Korea, it is essential to understand the differences in cultural norms and expectations between foreign workers and Korean employees. Companies should provide training to their employees on how to work with foreign workers and create a supportive environment for them. Additionally, companies should establish clear communication channels with foreign workers to address any issues or concerns they may have. By implementing these solutions, companies can create a more inclusive and diverse work environment that benefits both the company and the foreign workers.
# {'A_wins': 15, 'B_wins': 16, 'tie': 34, 'A_score': 193, 'B_score': 189}
# 0 0 Lupin Peter
# {'A_wins': 15, 'B_wins': 16, 'tie': 35, 'A_score': 193, 'B_score': 189}
# 10 6 Tax incentives for establishing a new banking or insurance A 10-year tax exemption is provided for income derived from a new banking or insurance business established in a financial hub area.
# {'A_wins': 16, 'B_wins': 16, 'tie': 35, 'A_score': 203, 'B_score': 195}
# 4 10 The source for the information on GDP growth in World Bank.
# {'A_wins': 16, 'B_wins': 17, 'tie': 35, 'A_score': 207, 'B_score': 205}
# 0 0 There are two national labor federations in Korea. There are two national labor federations in Korea.
# {'A_wins': 16, 'B_wins': 17, 'tie': 36, 'A_score': 207, 'B_score': 205}
# 0 0 World Values Survey World Values Survey
# {'A_wins': 16, 'B_wins': 17, 'tie': 37, 'A_score': 207, 'B_score': 205}
# 10 6 The balance sheet approach to expatriate compensation involves The balance sheet approach to expatriate compensation involves comparing the cost of living in the host country with that in the home country and adjusting the expatriate's salary to maintain the same standard of living.
# {'A_wins': 17, 'B_wins': 17, 'tie': 37, 'A_score': 217, 'B_score': 211}
# 2 6 The story ends with the bunisee law The story ends with the protagonist's realization that the world is not black and white, and that there are always two sides to every story.
# {'A_wins': 17, 'B_wins': 18, 'tie': 37, 'A_score': 219, 'B_score': 217}
# 4 10 No, there is no taxable event at grant No, there is no taxable event at grant or on the vesting date of stock.
# {'A_wins': 17, 'B_wins': 19, 'tie': 37, 'A_score': 223, 'B_score': 227}
# Error code: 429 - {'error_code': 'TOO_MANY_REQUESTS', 'message': {'en': "Thanks for loving our service. You've sent too many requests in a short time. Please try again later. For further help, contact console@upstage.ai"}}
# 9 7 Korea has 17 provinces and cities. Korea has 16 provinces and cities.
# {'A_wins': 18, 'B_wins': 19, 'tie': 37, 'A_score': 232, 'B_score': 234}
# 0 0 Language barriers, cultural differences, and difficulty finding employment Expatriate spouses may face challenges such as language barriers, lack of social networks, and difficulty finding employment.
# {'A_wins': 18, 'B_wins': 19, 'tie': 38, 'A_score': 232, 'B_score': 234}
# 4 10 PwC's office in Toronto, Canada PwC Canada
# {'A_wins': 18, 'B_wins': 20, 'tie': 38, 'A_score': 236, 'B_score': 244}
# 8 6 Korean business leaders often set ambitious goals for their companies Korean business leaders set ambitious goals for their companies and employees by setting high standards and expectations, and by creating a culture of hard work and dedication. They often push their employees to work long hours and to strive for excellence in their work.
# {'A_wins': 19, 'B_wins': 20, 'tie': 38, 'A_score': 244, 'B_score': 250}
# Error code: 429 - {'error_code': 'TOO_MANY_REQUESTS', 'message': {'en': "Thanks for loving our service. You've sent too many requests in a short time. Please try again later. For further help, contact console@upstage.ai"}}
# 0 0 The top sectors of outbound M&As in The top sectors of outbound M&As in South Korea by value are financial services, consumer goods, and technology.
# {'A_wins': 19, 'B_wins': 20, 'tie': 39, 'A_score': 244, 'B_score': 250}
# 0 0 The title of the article is "Political The title of the article is "Political economy of Korean development after liberation: A critical reflection."
# {'A_wins': 19, 'B_wins': 20, 'tie': 40, 'A_score': 244, 'B_score': 250}
# 4 9 Mismanagement in reforming PE&SE could Mismanagement in reforming PE&SE could have a negative impact on Korea's business environment, as it could lead to a lack of transparency and accountability in the system, which could discourage foreign investment and harm the country's reputation as a business destination.
# {'A_wins': 19, 'B_wins': 21, 'tie': 40, 'A_score': 248, 'B_score': 259}
# 0 0 The main aim of the 'Creative Economy The main aim of the 'Creative Economy' initiative introduced by the Korean government in 2013 is to promote the development of creative industries and to enhance the country's competitiveness in the global market.
# {'A_wins': 19, 'B_wins': 21, 'tie': 41, 'A_score': 248, 'B_score': 259}
# Error code: 429 - {'error_code': 'TOO_MANY_REQUESTS', 'message': {'en': "Thanks for loving our service. You've sent too many requests in a short time. Please try again later. For further help, contact console@upstage.ai"}}
# 0 0 The author of "Doing Business in Korea" The author of "Doing Business in Korea" is Dr. Michael J. Moore.
# {'A_wins': 19, 'B_wins': 21, 'tie': 42, 'A_score': 248, 'B_score': 259}
# 0 0 In South Korea, the main determinants of internet The main determinants of internet standards adoption, as demonstrated by the case of South Korea, are government policy, market competition, and technological innovation.
# {'A_wins': 19, 'B_wins': 21, 'tie': 43, 'A_score': 248, 'B_score': 259}
# 0 0 No, utility costs paid by an employer are not No, utility costs paid by an employer are not taxable to the employee.
# {'A_wins': 19, 'B_wins': 21, 'tie': 44, 'A_score': 248, 'B_score': 259}
# 0 0 The Worldbank's website for information on South http://www.worldbank.org/en/country/south-korea.
# {'A_wins': 19, 'B_wins': 21, 'tie': 45, 'A_score': 248, 'B_score': 259}
# 6 8 Some popular retailers in the Korean market include E Some popular retailers in the Korean market include E-Mart, Homeplus, Lotte Mart, and Costco.
# {'A_wins': 19, 'B_wins': 22, 'tie': 45, 'A_score': 254, 'B_score': 267}
# 2 5 moonROK was founded in 20 moonROK was founded in 2012 by a group of K-pop fans.
# {'A_wins': 19, 'B_wins': 23, 'tie': 45, 'A_score': 256, 'B_score': 272}
# 10 6 The consideration amount for a qualified foreign Non-res The consideration amount for a qualified foreign Non-resident Income Taxation technician/engineer providing services in Korea under an engineering technology inducement agreement is KRW 100,000 or more.
# {'A_wins': 20, 'B_wins': 23, 'tie': 45, 'A_score': 266, 'B_score': 278}
# 0 0 FBA stands for Foreign Business Association. FBA stands for foreign business administration.
# {'A_wins': 20, 'B_wins': 23, 'tie': 46, 'A_score': 266, 'B_score': 278}
# 0 0 PwC's office in Frankfurt, Germany PwC Germany
# {'A_wins': 20, 'B_wins': 23, 'tie': 47, 'A_score': 266, 'B_score': 278}
# Invalid json output: The AI assistant's response is not a single line answer and does not provide the location of PwC's office in San Francisco, USA. Therefore, I rate the answer as 1 (bad).
#
# {"score": 1}
# 0 0 The location of PwC's office in PwC US
# {'A_wins': 20, 'B_wins': 23, 'tie': 48, 'A_score': 266, 'B_score': 278}
# 10 3 The appendix of the report contains additional information and The appendix contains a list of abbreviations used in the report.
# {'A_wins': 21, 'B_wins': 23, 'tie': 48, 'A_score': 276, 'B_score': 281}
# Invalid json output: The provided answer is incomplete and does not fully address the question. It only mentions "Korea's top 60 start" without providing the location or any additional information. Therefore, I would rate the answer as 1, indicating a bad answer.
#
# {"score": 1}
# 2 6 Korea's top 60 start Korea's top 60 start-ups and K-Global 300 start-ups are located in Seoul.
# {'A_wins': 21, 'B_wins': 24, 'tie': 48, 'A_score': 278, 'B_score': 287}
# 0 0 A resident corporation is subject to corporate income tax on A resident corporation is taxed on its worldwide income, while a nonresident corporation is taxed only on its Korean-source income.
# {'A_wins': 21, 'B_wins': 24, 'tie': 49, 'A_score': 278, 'B_score': 287}
# 0 0 Korea's focus in terms of products Korea's focus in terms of products and industries is not provided in the information given.
# {'A_wins': 21, 'B_wins': 24, 'tie': 50, 'A_score': 278, 'B_score': 287}
# 0 0 Hedge funds were introduced in Korea in 2 Hedge funds were introduced in Korea in 2001.
# {'A_wins': 21, 'B_wins': 24, 'tie': 51, 'A_score': 278, 'B_score': 287}
# 2 6 Yongo ties are a type of knot used Yongo ties are informal, personal relationships that are based on trust and loyalty. They are often formed outside of the formal organizational structure and can be used to achieve goals that are not possible through formal channels. Yongo ties are often formed between individuals who share a common background or interest, such as alma mater, hometown, or hobbies. They are particularly important in Korean society, where they are used to navigate the complex social and organizional structures.
# {'A_wins': 21, 'B_wins': 25, 'tie': 51, 'A_score': 280, 'B_score': 293}
# 10 2 The deduction limit for entertainment expenses in excess of The deduction limit for entertainment expenses in excess of the tax limit is KRW 10 million.
# {'A_wins': 22, 'B_wins': 25, 'tie': 51, 'A_score': 290, 'B_score': 295}
# 0 0 The total value of outbound greenfield projects in The total value of outbound greenfield projects in the world is USD1.2 trillion.
# {'A_wins': 22, 'B_wins': 25, 'tie': 52, 'A_score': 290, 'B_score': 295}
# Error code: 429 - {'error_code': 'TOO_MANY_REQUESTS', 'message': {'en': "Thanks for loving our service. You've sent too many requests in a short time. Please try again later. For further help, contact console@upstage.ai"}}
# 6 8 To compute adequate prices, it is necessary to consider Other materials necessary for computing the adequate prices include the cost of materials, labor, and overheads, as well as the cost of capital and the time value of money.
# {'A_wins': 22, 'B_wins': 26, 'tie': 52, 'A_score': 296, 'B_score': 303}
# 10 4 The main focus of the provided information is on the The provided information focuses on the discussion of the Korean economy and its recent developments, with a particular emphasis on the country's economic growth, trade, and investment.
# {'A_wins': 23, 'B_wins': 26, 'tie': 52, 'A_score': 306, 'B_score': 307}
# Error code: 429 - {'error_code': 'TOO_MANY_REQUESTS', 'message': {'en': "Thanks for loving our service. You've sent too many requests in a short time. Please try again later. For further help, contact console@upstage.ai"}}
# 2 8 As of 2021, South Korea 4.2%
# {'A_wins': 23, 'B_wins': 27, 'tie': 52, 'A_score': 308, 'B_score': 315}
# 0 0 The subnational regions covered in Table 5 Table 5.12 covers Inbound FDI into Korea by subnational region.
# {'A_wins': 23, 'B_wins': 27, 'tie': 53, 'A_score': 308, 'B_score': 315}
# 0 0 The total number of inbound FDI notifications The total number of inbound FDI notifications to Korea from 2005 to 2017 is 35,000.
# {'A_wins': 23, 'B_wins': 27, 'tie': 54, 'A_score': 308, 'B_score': 315}
# 9 6 The close partnership between the Korean state and businesses led The close partnership between the Korean state and businesses led to the development of a system of crony capitalism, whereby the state and businesses worked together to achieve economic growth.
# {'A_wins': 24, 'B_wins': 27, 'tie': 54, 'A_score': 317, 'B_score': 321}
# 10 6 The investment thresholds for foreigners without F Foreigners without F-5 or F-6 visas must invest at least KRW 100 million to start a corporation or KRW 20 million to start a sole proprietorship.
# {'A_wins': 25, 'B_wins': 27, 'tie': 54, 'A_score': 327, 'B_score': 327}
# 0 0 The standard accounting period for businesses in Korea is one The standard accounting period for businesses in Korea is one year.
# {'A_wins': 25, 'B_wins': 27, 'tie': 55, 'A_score': 327, 'B_score': 327}
# 10 6 SIEs (Specialized Industry Employees) SIEs often find employment in the financial, legal, and consulting industries in Korea.
# {'A_wins': 26, 'B_wins': 27, 'tie': 55, 'A_score': 337, 'B_score': 333}
# 0 0 Yes, Korea is densely populated. Yes, Korea is densely populated.
# {'A_wins': 26, 'B_wins': 27, 'tie': 56, 'A_score': 337, 'B_score': 333}
# 2 10 The most important bilateral trade agreement ever undertaken The most important bilateral trade agreement ever undertaken by Korea is the Korea-US Free Trade Agreement (KORUS FTA).
# {'A_wins': 26, 'B_wins': 28, 'tie': 56, 'A_score': 339, 'B_score': 343}
# 10 6 Doyle (2003) identifies Doyle (2003) identifies the key features of marketing management as the ability to identify and understand customer needs, the ability to create and deliver value to customers, the ability to manage the marketing mix (product, price, promotion, and place), and the ability to create and maintain a positive image of the company and its products.
# {'A_wins': 27, 'B_wins': 28, 'tie': 56, 'A_score': 349, 'B_score': 349}
# 0 0 A key success factor for foreign companies with major R A key success factor for foreign companies with major R&D activities in Korea is to establish a strong network with local universities and research institutions to access local talent and knowledge.
# {'A_wins': 27, 'B_wins': 28, 'tie': 57, 'A_score': 349, 'B_score': 349}
# 0 0 The largest chaebols in South Korea are Samsung The largest chaebols in South Korea are Samsung, LG, Hyundai, SK, and Kia.
# {'A_wins': 27, 'B_wins': 28, 'tie': 58, 'A_score': 349, 'B_score': 349}
# 2 6 "The Asian Flu" "The Myth of Asia's Miracle"
# {'A_wins': 27, 'B_wins': 29, 'tie': 58, 'A_score': 351, 'B_score': 355}
# 10 6 The most common types of tax holidays in Korea are The most common types of tax holidays in Korea are 5-year tax exemption for income derived from exporting goods and services and 5-year tax exemption for income derived from exporting goods and services.
# {'A_wins': 28, 'B_wins': 29, 'tie': 58, 'A_score': 361, 'B_score': 361}
# 10 2 In Korea, the following types of capital account transactions Capital account transactions that require prior permission in Korea include: (1) acquisition of shares in a domestic company by a non-resident, (2) acquisition of real estate in Korea by a non-resident, (3) acquisition of bonds issued by a non-resident, (4) acquisition of securities issued by a non-resident, (5) acquisition of bonds issued by a non-resident, (6) acquisition of securities issued by a non-resident, (7) acquisition of bonds issued by a non-resident, (8) acquisition of securities issued by a non-resident, (9) acquisition of bonds issued by a non-resident, (10) acquisition of securities issued by a non-resident, (11) acquisition of bonds issued by a non-resident, (12) acquisition of securities issued by a non-resident, (13) acquisition of bonds issued by a non-resident, (14) acquisition of securities issued by a non-resident, (15) acquisition of bonds issued by a non-resident, (16) acquisition of securities issued by a non-resident, (17) acquisition of bonds issued by a non-resident, (18) acquisition of securities issued by a non-resident, (19) acquisition of bonds issued by a non-resident, (20) acquisition of securities issued by a non-resident, (21) acquisition of bonds issued by a non-resident, (22) acquisition of securities issued by a non-resident, (23) acquisition of bonds issued by a non-resident, (24) acquisition of securities issued by a non-resident, (25) acquisition of bonds issued by a non-resident, (26) acquisition of securities issued by a non-resident, (27) acquisition of bonds issued by a non-resident, (28) acquisition of securities issued by a non-resident, (29) acquisition of bonds issued by a non-resident, (30) acquisition of securities issued by a non-resident, (31) acquisition of bonds issued by a non-resident, (32) acquisition of securities issued by a non-resident, (33) acquisition of bonds issued by a non-resident, (34) acquisition of securities issued by a non-resident, (35) acquisition of bonds issued by a non-resident, (36) acquisition of securities issued by a non-resident, (37) acquisition of bonds issued by a non-resident, (38) acquisition of securities issued by a non-resident, (39) acquisition of bonds issued by a non-resident, (40) acquisition of securities issued by a non-resident, (41) acquisition of bonds issued by a non-resident, (42) acquisition of securities issued by a non-resident, (43) acquisition of bonds issued by a non-resident, (44) acquisition of securities issued by a non-resident, (45) acquisition of bonds issued by a non-resident, (46) acquisition of securities issued by a non-resident, (47) acquisition of bonds issued by a non-resident, (48) acquisition of securities issued by a non-resident, (49) acquisition of bonds issued by a non-resident, (50) acquisition of securities issued by a non-resident, (51) acquisition of bonds issued by a non-resident, (52) acquisition of securities issued by a non-resident, (53) acquisition of bonds issued by a non-resident, (54) acquisition of securities issued by a non-resident, (55) acquisition of bonds issued by a non-resident, (56) acquisition of securities issued by a non-resident, (57) acquisition of bonds issued by a non-resident, (58) acquisition of securities issued by a non-resident, (59) acquisition of bonds issued by a non-resident, (60) acquisition of securities issued by a non-resident, (61) acquisition of bonds issued by a non-resident, (62) acquisition of securities issued by a non-resident, (63) acquisition of bonds issued by a non-resident, (64) acquisition of securities issued by a non-resident, (6
# {'A_wins': 29, 'B_wins': 29, 'tie': 58, 'A_score': 371, 'B_score': 363}
# 0 0 PwC's office in Cleveland, USA PwC US
# {'A_wins': 29, 'B_wins': 29, 'tie': 59, 'A_score': 371, 'B_score': 363}
# 0 0 The sixth section of the report discusses the potential The sixth section is about the taxation of foreign companies in Korea, which begins on page 43.
# {'A_wins': 29, 'B_wins': 29, 'tie': 60, 'A_score': 371, 'B_score': 363}
# 7 10 Korean consumers' sophistication and demand for As Korean products have become more popular and their quality has improved, consumers have become more sophisticated and demanding. They now expect high-quality products and services, and are willing to pay a premium for them. This has led to a rise in the popularity of Korean products and services, as they are seen as a symbol of quality and sophistication.
# {'A_wins': 29, 'B_wins': 30, 'tie': 60, 'A_score': 378, 'B_score': 373}
# 10 2 The impeachment of Park Geun-H The fall of Park Geun-Hye's presidency was triggered by the 2016 event.
# {'A_wins': 30, 'B_wins': 30, 'tie': 60, 'A_score': 388, 'B_score': 375}
# 0 0 Language barriers, cultural differences, and adapting The main challenges faced by expatriates in Korea include language barriers, cultural differences, and the need to adapt to a new environment.
# {'A_wins': 30, 'B_wins': 30, 'tie': 61, 'A_score': 388, 'B_score': 375}
# 10 6 Seoul GSC offers a range of benefits to Seoul GSC offers a variety of benefits to participating companies, including access to a network of Korean and foreign business partners, assistance in market entry and expansion, and support in finding potential business partners and customers.
# {'A_wins': 31, 'B_wins': 30, 'tie': 61, 'A_score': 398, 'B_score': 381}
# 0 0 Foreigners in Korea may be eligible for tax benefits Foreigners who have been employed in Korea for less than five years are exempt from tax on their foreign income.
# {'A_wins': 31, 'B_wins': 30, 'tie': 62, 'A_score': 398, 'B_score': 381}
# Error code: 429 - {'error_code': 'TOO_MANY_REQUESTS', 'message': {'en': "Thanks for loving our service. You've sent too many requests in a short time. Please try again later. For further help, contact console@upstage.ai"}}
# 0 0 The IMF rescue package had a significant impact on The IMF rescue package led to a restructuring of Korea's economic policies, including the introduction of more market-oriented policies.
# {'A_wins': 31, 'B_wins': 30, 'tie': 63, 'A_score': 398, 'B_score': 381}
# 2 10 Chapters 1-6 The chapters in Part III are:
# {'A_wins': 31, 'B_wins': 31, 'tie': 63, 'A_score': 400, 'B_score': 391}
# 0 0 The investment incentives available for local tax exemption Investment incentives available for local tax exemption in accordance with local ordinances include exemption from local taxes such as property tax, registration tax, and local income tax for a certain period of time.
# {'A_wins': 31, 'B_wins': 31, 'tie': 64, 'A_score': 400, 'B_score': 391}
# Error code: 429 - {'error_code': 'TOO_MANY_REQUESTS', 'message': {'en': "Thanks for loving our service. You've sent too many requests in a short time. Please try again later. For further help, contact console@upstage.ai"}}
# 0 0 The Uppsala process theory of internationalization The Uppsala process theory of internationalization is a model that describes the stages a firm goes through as it internationalizes its business. It was developed by researchers at Uppsala University in Sweden.
# {'A_wins': 31, 'B_wins': 31, 'tie': 65, 'A_score': 400, 'B_score': 391}
# 10 6 The informal network in Korea's business environment The informal network created a shadow world in Korea's business environment by making it difficult for foreign companies to enter the market and compete with local companies.
# {'A_wins': 32, 'B_wins': 31, 'tie': 65, 'A_score': 410, 'B_score': 397}
# 10 2 The context of the provided information is not specified in The provided information is about the context of the information.
# {'A_wins': 33, 'B_wins': 31, 'tie': 65, 'A_score': 420, 'B_score': 399}
# 2 8 Title VII of the Civil Rights Act of 1 The Equal Employment Opportunity Law prohibits gender discrimination against any worker.
# {'A_wins': 33, 'B_wins': 32, 'tie': 65, 'A_score': 422, 'B_score': 407}
# 0 0 Language barriers, cultural differences, and regulatory compliance are Foreign firms exporting to Korea face challenges such as high competition from local firms, the need to adapt to Korean consumer preferences, and the potential for Korean firms to reverse engineer their products.
# {'A_wins': 33, 'B_wins': 32, 'tie': 66, 'A_score': 422, 'B_score': 407}
# 10 7 The previous seniority-based system at DHL DHL Korea faced problems with the previous seniority-based system, as it was not flexible enough to meet the needs of the business.
# {'A_wins': 34, 'B_wins': 32, 'tie': 66, 'A_score': 432, 'B_score': 414}
# 0 0 Yes, there are exceptions to the anti-tax Yes, there are exceptions to the anti-tax haven rules.
# {'A_wins': 34, 'B_wins': 32, 'tie': 67, 'A_score': 432, 'B_score': 414}
# 10 7 The main argument of the chapter is that the network The chapter argues that the network view of the Korean society and business environment is a useful lens to understand the Korean society and business environment, as it helps to explain the importance of informal networks and relationships in Korean society and their impact on business.
# {'A_wins': 35, 'B_wins': 32, 'tie': 67, 'A_score': 442, 'B_score': 421}
# 0 0 "A History of East Asia: From the Or The title of the book is "East Asia: A Cultural and Social History."
# {'A_wins': 35, 'B_wins': 32, 'tie': 68, 'A_score': 442, 'B_score': 421}
# 0 0 The percentage of inbound FDI into Korea with 55.6%
# {'A_wins': 35, 'B_wins': 32, 'tie': 69, 'A_score': 442, 'B_score': 421}
# 0 0 The economic participation rate in Korea for the population aged 65.3%
# {'A_wins': 35, 'B_wins': 32, 'tie': 70, 'A_score': 442, 'B_score': 421}
# 0 0 Yes, penalties can be waived for transfer Yes, penalties can be waived for transfer pricing adjustments.
# {'A_wins': 35, 'B_wins': 32, 'tie': 71, 'A_score': 442, 'B_score': 421}
# 0 0 The taxable income for a branch office in Korea The taxable income for a branch office in Korea is the same as that of a domestic corporation.
# {'A_wins': 35, 'B_wins': 32, 'tie': 72, 'A_score': 442, 'B_score': 421}
# 2 10 The information on GDP per capita in South 15 March 2019.
# {'A_wins': 35, 'B_wins': 33, 'tie': 72, 'A_score': 444, 'B_score': 431}
# 2 4 70.5% 60%
# {'A_wins': 35, 'B_wins': 34, 'tie': 72, 'A_score': 446, 'B_score': 435}
# 10 8 An agent of a foreign corporation is considered a permanent An agent of a foreign corporation is considered a PE if the agent has authority to conclude contracts on behalf of the foreign corporation and habitually performs such activities.
# {'A_wins': 36, 'B_wins': 34, 'tie': 72, 'A_score': 456, 'B_score': 443}
# 0 0 Recruitment and retention in Korea saw significant After 1987, recruitment and retention changed significantly in Korea. The government's intervention in the labor market was reduced, and the labor market became more flexible. Companies began to hire workers on a temporary basis, and the number of non-regular workers increased. The labor market became more segmented, with regular and non-regular workers having different employment conditions and rights. The labor market also became more competitive, with companies focusing on cost reduction and efficiency. The number of strikes and labor disputes increased, and labor unions became more active in demanding better working conditions and wages. The government's role in labor-management relations was reduced, and the focus shifted towards market-based solutions.
# {'A_wins': 36, 'B_wins': 34, 'tie': 73, 'A_score': 456, 'B_score': 443}
# 0 0 PwC's office in Amsterdam, Netherlands PwC Netherlands
# {'A_wins': 36, 'B_wins': 34, 'tie': 74, 'A_score': 456, 'B_score': 443}
# 5 7 The bbali-bbali mindset in The bbali-bbali mindset has a significant impact on the Korean business culture, as it is deeply ingrained in the society and can be seen in various aspects of business interactions. It is important for foreigners to understand and adapt to this mindset in order to successfully navigate the Korean business environment.
# {'A_wins': 36, 'B_wins': 35, 'tie': 74, 'A_score': 461, 'B_score': 450}
# 10 4 The article discussing the 4 P classification of the The article discussing the 4 P classification of the marketing mix is "Marketing Mix."
# {'A_wins': 37, 'B_wins': 35, 'tie': 74, 'A_score': 471, 'B_score': 454}
# 0 0 Japan Japan
# {'A_wins': 37, 'B_wins': 35, 'tie': 75, 'A_score': 471, 'B_score': 454}
# Task exception was never retrieved
# future: <Task finished name='Task-1446' coro=<AsyncClient.aclose() done, defined at c:\Users\emon\anaconda3\Lib\site-packages\httpx\_client.py:1996> exception=AttributeError("'AsyncHttpxClientWrapper' object has no attribute '_transport'")>
# Traceback (most recent call last):
#   File "c:\Users\emon\anaconda3\Lib\site-packages\httpx\_client.py", line 2003, in aclose
#     await self._transport.aclose()
#           ^^^^^^^^^^^^^^^
# AttributeError: 'AsyncHttpxClientWrapper' object has no attribute '_transport'
